# %%
# !pip install imageio
# Out:
# ...
#      |████████████████████████████████| 3.3MB 2.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.1MB 84.3MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import imageio
imr = imageio.imread("/srgan/data/ptest/lr/1.png")

# %%
import numpy as np

# %%
print(r)
np.mean(r)
t1=(r-np.mean(r))*(255/(121-38))
print(np.max(t1)-np.min(t1))
# Out:
# [ 53  61  65  72  76  79  90 109 109 111 107 106 104 104 109 111 112  85
#   57  52  52  51  51  51  53  53  58  56  58  57  50  52  54  54  53  51
#   52  50  51  53  53  53  54  55  57  56  54  56  55  52  54  54  55  56
#   58  58  58  58  57  58  57  57  57  58]

# %%
# !pip install scipy==1.2.0
# Out:
# ...
#      |████████████████████████████████| 26.6MB 1.8MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from scipy.misc import imresize

# %%
a=imr[:,:,0]

# %%
np.set_printoptions(threshold=np.inf)
print(a)
# Out:
# [[ 33  43  56  67  76  73  90 117 133 140 136 134 133 138 139 138 138  89
#    30  35  33  31  31  31  28  34  31  30  31  34  29  29  28  28  29  29
#    29  29  29  29  29  28  30  30  29  29  29  32  28  29  29  30  30  31
#    32  31  31  31  30  31  31  30  31  34]
#  [ 30  33  37  51  67  60  69  94 138 139 138 136 135 141 144 140 137  86
#    36  34  33  32  32  32  31  33  31  31  29  29  25  29  31  29  28  30
#    29  29  29  27  29  29  28  29  31  29  32  44  55  37  30  30  30  30
#    32  31  31  30  30  31  31  31  30  32]
#  [ 29  31  38  51  64  60  56  84 139 136 142 133 131 138 142 138 135  93
#    40  33  34  33  32  33  34  33  30  29  27  26  23  29  31  29  30  30
#    30  29  28  26  27  29  28  29  30  29  37  62  70  42  31  31  30  29
#    30  31  30  31  31  29  31  31  30  32]
#  [ 30  33  36  50  74  57  56  84 127 137 141 135 130 133 136 136 135 103
#    37  35  35  32  33  33  33  31  28  26  27  26  28  30  29  28  30  29
# ...

# %%
from scipy.misc import imread, imresize
imr2 = imageio.imread("/srgan/data/ptest/lr/1.png")
imr1 = imread("/srgan/data/ptest/lr/1.png")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
a=imr1/127.5 - 1
np.max(a)
# Out:
# 0.12941176470588234

# %%
imr2
# Out:
# Array([[[ 33,  53,  60],
#         [ 43,  61,  65],
#         [ 56,  65,  68],
#         [ 67,  72,  73],
#         [ 76,  76,  76],
#         [ 73,  79,  77],
#         [ 90,  90,  86],
#         [117, 109,  99],
#         [133, 109,  99],
#         [140, 111,  98],
#         [136, 107,  95],
#         [134, 106,  90],
#         [133, 104,  91],
#         [138, 104,  92],
#         [139, 109,  94],
#         [138, 111,  97],
#         [138, 112, 101],
#         [ 89,  85,  83],
#         [ 30,  57,  60],
#         [ 35,  52,  58],
#         [ 33,  52,  57],
#         [ 31,  51,  56],
#         [ 31,  51,  56],
#         [ 31,  51,  57],
#         [ 28,  53,  56],
#         [ 34,  53,  60],
#         [ 31,  58,  59],
#         [ 30,  56,  59],
#         [ 31,  58,  59],
#         [ 34,  57,  59],
#         [ 29,  50,  55],
#         [ 29,  52,  55],
#         [ 28,  54,  56],
#         [ 28,  54,  57],
#         [ 29,  53,  58],
#         [ 29,  51,  58],
#         [ 29,  52,  57],
# ...

# %%
np.histogram(imres,bins=range(0,255))
# Out:
# (array([  1,   0,   5,   0,  35,   0,  91,   0, 258,   0, 499,   0,   0,
#         623,   0, 601,   0, 383,   0, 219,   0, 138,   0,  96,   0,  75,
#           0,  61,   0,  53,   0,  45,   0,  32,   0,   0,  37,   0,  29,
#           0,  17,   0,  18,   0,  21,   0,  20,   0,  12,   0,  10,   0,
#          12,   0,  17,   0,  10,   0,   0,  10,   0,  16,   0,   6,   0,
#           5,   0,   7,   0,   6,   0,  10,   0,   8,   0,   6,   0,   4,
#           0,   9,   0,   0,   9,   0,   5,   0,   7,   0,   6,   0,   6,
#           0,   7,   0,   6,   0,   6,   0,   8,   0,   7,   0,   8,   0,
#           0,   1,   0,   6,   0,   4,   0,   1,   0,   7,   0,   5,   0,
#           8,   0,   8,   0,   3,   0,   6,   0,   5,   0,   0,   3,   0,
#           5,   0,   3,   0,   8,   0,   5,   0,   4,   0,   6,   0,   5,
#           0,   5,   0,   3,   0,   8,   0,   4,   0,   0,   3,   0,   2,
#           0,   4,   0,   1,   0,   4,   0,   5,   0,   1,   0,   4,   0,
# ...

# %%
np.max(imres[0:64,0:64,1])
# Out:
# 207

# %%
imageio.imwrite('test1.png',imres)

# %%
import scipy
#img = scipy.misc.ascent()
img = imageio.imread("/srgan/data/ptest/hr/1.png")
print(img.min(), img.mean(), img.max())
img2 = scipy.misc.imresize(img.astype('uint8'), [1000, 1000])
print(img2.min(), img2.mean(), img2.max())
img2 = scipy.misc.imresize(img.astype('float32'), [1000, 1000])
print(img2.min(), img2.mean(), img2.max())
# Out:
# 16 68.29375712076823 199
# 16 68.29746366666667 195
# 0 72.87164066666666 250
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   import sys
